# %%
import asyncio

from pyinjective.async_client import AsyncClient
from pyinjective.core.network import Network


async def main() -> None:
    network = Network.local()
    client = AsyncClient(network)
    account_address = "inj1jddhqk6egwcwrwzev5wjeneht0ykmlwhcehc4z"
    subacc_list = await client.fetch_subaccounts_list(account_address)
    return subacc_list


subacc_list = await main()
subacc_list
# Out:
# {'subaccounts': ['0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000001',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000002',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000003',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000004',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000005',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000006',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000007',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000008',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000009',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000000a',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000000',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000000b',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000000c',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000000d',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000000e',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000000f',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000010',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000011',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000012',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000013',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000014',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000015',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000016',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000017',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000018',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000019',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000001a',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000001b',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000001c',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000001d',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000001e',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000001f',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000020',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000021',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000022',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000023',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000024',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000025',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000026',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000027',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000028',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000029',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000032',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000033',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000035',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000036',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000064',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000065',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000066',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000067',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd7000000000000000000000031',
#   '0x935b705b5943b0e1b859651d2ccf375bc96dfdd700000000000000000000003c']}
